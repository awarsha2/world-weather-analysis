# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = lat_lngs

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 746

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]    
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | namatanai
# Processing Record 3 of Set 1 | pevek
# Processing Record 4 of Set 1 | faanui
# Processing Record 5 of Set 1 | mount gambier
# Processing Record 6 of Set 1 | harper
# Processing Record 7 of Set 1 | saskylakh
# Processing Record 8 of Set 1 | ixtapa
# Processing Record 9 of Set 1 | lebu
# Processing Record 10 of Set 1 | ciudad bolivar
# Processing Record 11 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 1 | castro
# Processing Record 13 of Set 1 | kavieng
# Processing Record 14 of Set 1 | kirakira
# Processing Record 15 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | cabo san lucas
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | vangaindrano
# Processing Record 20 of Set 1 | tuktoyaktuk
# Processing Record 21 of Set 1 | merauke
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | vila do maio
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | palmer
# Processing Record 28 of Set 1 | huilong
# Processing Record 29 of Set 1 | nanortalik
# Processing Record 30 of Set 1 | hobart
# Processing Record 31 of Set 1 | hualmay
# Processing Record 32 of Set 1 | ketchikan
# Processing Record 33 of Set 1 | key west
# Processing Record 34 of Set 1 | guerrero negro
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | saldanha
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | mahaicony
# City not found. Skipping...
# Processing Record 40 of Set 1 | gat
# Processing Record 41 of Set 1 | sisimiut
# Processing Record 42 of Set 1 | ribeira grande
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | makung
# City not found. Skipping...
# Processing Record 45 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 1 | bambous virieux
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | qaanaaq
# Processing Record 49 of Set 1 | cerrito
# Processing Record 50 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 2 | liberal
# Processing Record 2 of Set 2 | lompoc
# Processing Record 3 of Set 2 | abu samrah
# Processing Record 4 of Set 2 | hithadhoo
# Processing Record 5 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 6 of Set 2 | namibe
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | meulaboh
# Processing Record 9 of Set 2 | hobyo
# Processing Record 10 of Set 2 | avarua
# Processing Record 11 of Set 2 | atuona
# Processing Record 12 of Set 2 | bunia
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | nikolskoye
# Processing Record 15 of Set 2 | muros
# Processing Record 16 of Set 2 | lavrentiya
# Processing Record 17 of Set 2 | fortuna
# Processing Record 18 of Set 2 | nouadhibou
# Processing Record 19 of Set 2 | cessnock
# Processing Record 20 of Set 2 | tomohon
# Processing Record 21 of Set 2 | laguna
# Processing Record 22 of Set 2 | hilo
# Processing Record 23 of Set 2 | naze
# Processing Record 24 of Set 2 | caxito
# Processing Record 25 of Set 2 | diebougou
# Processing Record 26 of Set 2 | mahebourg
# Processing Record 27 of Set 2 | novocheremshansk
# Processing Record 28 of Set 2 | katsiveli
# City not found. Skipping...
# Processing Record 29 of Set 2 | samarai
# Processing Record 30 of Set 2 | lagoa
# Processing Record 31 of Set 2 | arman
# Processing Record 32 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 2 | saint george
# Processing Record 34 of Set 2 | labuhan
# Processing Record 35 of Set 2 | iralaya
# Processing Record 36 of Set 2 | barrow
# Processing Record 37 of Set 2 | khatanga
# Processing Record 38 of Set 2 | ust-tsilma
# Processing Record 39 of Set 2 | mar del plata
# Processing Record 40 of Set 2 | flinders
# Processing Record 41 of Set 2 | puerto ayora
# Processing Record 42 of Set 2 | constitucion
# Processing Record 43 of Set 2 | bocaiuva
# Processing Record 44 of Set 2 | karkaralinsk
# City not found. Skipping...
# Processing Record 45 of Set 2 | tiksi
# Processing Record 46 of Set 2 | caravelas
# Processing Record 47 of Set 2 | jijiang
# Processing Record 48 of Set 2 | auki
# Processing Record 49 of Set 2 | saint-philippe
# Processing Record 50 of Set 2 | kapaa
# Processing Record 1 of Set 3 | georgetown
# Processing Record 2 of Set 3 | san quintin
# Processing Record 3 of Set 3 | margate
# Processing Record 4 of Set 3 | berbera
# Processing Record 5 of Set 3 | bindura
# Processing Record 6 of Set 3 | farah
# Processing Record 7 of Set 3 | tuatapere
# Processing Record 8 of Set 3 | arraial do cabo
# Processing Record 9 of Set 3 | cuamba
# Processing Record 10 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 3 | buraydah
# Processing Record 12 of Set 3 | aktash
# Processing Record 13 of Set 3 | port elizabeth
# Processing Record 14 of Set 3 | pak phanang
# Processing Record 15 of Set 3 | boroaia
# Processing Record 16 of Set 3 | vila velha
# Processing Record 17 of Set 3 | cap malheureux
# Processing Record 18 of Set 3 | masakin
# Processing Record 19 of Set 3 | cookshire
# City not found. Skipping...
# Processing Record 20 of Set 3 | isangel
# Processing Record 21 of Set 3 | kaupanger
# Processing Record 22 of Set 3 | mayo
# Processing Record 23 of Set 3 | airai
# Processing Record 24 of Set 3 | san cristobal
# Processing Record 25 of Set 3 | cayenne
# Processing Record 26 of Set 3 | douglas
# Processing Record 27 of Set 3 | souillac
# Processing Record 28 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 3 | antequera
# Processing Record 30 of Set 3 | bredasdorp
# Processing Record 31 of Set 3 | millinocket
# Processing Record 32 of Set 3 | provideniya
# Processing Record 33 of Set 3 | sarankhola
# Processing Record 34 of Set 3 | udachnyy
# Processing Record 35 of Set 3 | camacha
# Processing Record 36 of Set 3 | aklavik
# Processing Record 37 of Set 3 | thompson
# Processing Record 38 of Set 3 | chaohu
# Processing Record 39 of Set 3 | hoi an
# Processing Record 40 of Set 3 | tasiilaq
# Processing Record 41 of Set 3 | bella vista
# Processing Record 42 of Set 3 | takapau
# Processing Record 43 of Set 3 | hasaki
# Processing Record 44 of Set 3 | jishou
# Processing Record 45 of Set 3 | stolac
# Processing Record 46 of Set 3 | malatya
# Processing Record 47 of Set 3 | belaya gora
# Processing Record 48 of Set 3 | honningsvag
# Processing Record 49 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 50 of Set 3 | brattleboro
# Processing Record 1 of Set 4 | richards bay
# Processing Record 2 of Set 4 | sao filipe
# Processing Record 3 of Set 4 | maceio
# Processing Record 4 of Set 4 | carnarvon
# Processing Record 5 of Set 4 | bethel
# Processing Record 6 of Set 4 | yulara
# Processing Record 7 of Set 4 | ballina
# Processing Record 8 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 4 | tornio
# Processing Record 10 of Set 4 | mantua
# Processing Record 11 of Set 4 | ponta do sol
# Processing Record 12 of Set 4 | esperance
# Processing Record 13 of Set 4 | neiafu
# Processing Record 14 of Set 4 | coquimbo
# Processing Record 15 of Set 4 | yanan
# City not found. Skipping...
# Processing Record 16 of Set 4 | okhotsk
# Processing Record 17 of Set 4 | svobodnyy
# Processing Record 18 of Set 4 | aripuana
# Processing Record 19 of Set 4 | salalah
# Processing Record 20 of Set 4 | shache
# Processing Record 21 of Set 4 | san patricio
# Processing Record 22 of Set 4 | dikson
# Processing Record 23 of Set 4 | voh
# Processing Record 24 of Set 4 | klaksvik
# Processing Record 25 of Set 4 | padang
# Processing Record 26 of Set 4 | dingle
# Processing Record 27 of Set 4 | gubkin
# Processing Record 28 of Set 4 | port lincoln
# Processing Record 29 of Set 4 | bacuit
# City not found. Skipping...
# Processing Record 30 of Set 4 | nijar
# Processing Record 31 of Set 4 | hirara
# Processing Record 32 of Set 4 | mount isa
# Processing Record 33 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 35 of Set 4 | east london
# Processing Record 36 of Set 4 | touros
# Processing Record 37 of Set 4 | luanda
# Processing Record 38 of Set 4 | chokurdakh
# Processing Record 39 of Set 4 | pinega
# Processing Record 40 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 4 | south sioux city
# Processing Record 42 of Set 4 | kimberley
# Processing Record 43 of Set 4 | chimbote
# Processing Record 44 of Set 4 | birao
# Processing Record 45 of Set 4 | zhigansk
# Processing Record 46 of Set 4 | hambantota
# Processing Record 47 of Set 4 | kruisfontein
# Processing Record 48 of Set 4 | quatre cocos
# Processing Record 49 of Set 4 | akhmim
# Processing Record 50 of Set 4 | ganzhou
# Processing Record 1 of Set 5 | marv dasht
# City not found. Skipping...
# Processing Record 2 of Set 5 | aleksandrovka
# Processing Record 3 of Set 5 | sheridan
# Processing Record 4 of Set 5 | ribeira brava
# Processing Record 5 of Set 5 | kaitangata
# Processing Record 6 of Set 5 | olafsvik
# Processing Record 7 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 8 of Set 5 | buala
# Processing Record 9 of Set 5 | new norfolk
# Processing Record 10 of Set 5 | alice springs
# Processing Record 11 of Set 5 | iqaluit
# Processing Record 12 of Set 5 | vrangel
# Processing Record 13 of Set 5 | villavicencio
# Processing Record 14 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 5 | puerto escondido
# Processing Record 16 of Set 5 | avera
# Processing Record 17 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 5 | jalu
# Processing Record 19 of Set 5 | chabahar
# Processing Record 20 of Set 5 | portland
# Processing Record 21 of Set 5 | ahuimanu
# Processing Record 22 of Set 5 | shakiso
# Processing Record 23 of Set 5 | itarema
# Processing Record 24 of Set 5 | shingu
# Processing Record 25 of Set 5 | sault sainte marie
# Processing Record 26 of Set 5 | ponta delgada
# Processing Record 27 of Set 5 | kavaratti
# Processing Record 28 of Set 5 | spring valley
# Processing Record 29 of Set 5 | zhezkazgan
# Processing Record 30 of Set 5 | maragogi
# Processing Record 31 of Set 5 | kahului
# Processing Record 32 of Set 5 | ormond beach
# Processing Record 33 of Set 5 | omsukchan
# Processing Record 34 of Set 5 | torbay
# Processing Record 35 of Set 5 | newport
# Processing Record 36 of Set 5 | yershov
# Processing Record 37 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 5 | athens
# Processing Record 39 of Set 5 | ksenyevka
# City not found. Skipping...
# Processing Record 40 of Set 5 | stamford
# Processing Record 41 of Set 5 | griffith
# Processing Record 42 of Set 5 | komsomolskiy
# Processing Record 43 of Set 5 | kungurtug
# Processing Record 44 of Set 5 | seoul
# Processing Record 45 of Set 5 | geraldton
# Processing Record 46 of Set 5 | narsaq
# Processing Record 47 of Set 5 | bilibino
# Processing Record 48 of Set 5 | cliza
# Processing Record 49 of Set 5 | kainantu
# Processing Record 50 of Set 5 | marovoay
# Processing Record 1 of Set 6 | prince rupert
# Processing Record 2 of Set 6 | buariki
# City not found. Skipping...
# Processing Record 3 of Set 6 | longyearbyen
# Processing Record 4 of Set 6 | bardiyah
# Processing Record 5 of Set 6 | grand gaube
# Processing Record 6 of Set 6 | mokrousovo
# Processing Record 7 of Set 6 | charala
# Processing Record 8 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 9 of Set 6 | tevaitoa
# Processing Record 10 of Set 6 | hirado
# Processing Record 11 of Set 6 | amarante do maranhao
# Processing Record 12 of Set 6 | wawa
# Processing Record 13 of Set 6 | pisco
# Processing Record 14 of Set 6 | nara
# Processing Record 15 of Set 6 | nuuk
# Processing Record 16 of Set 6 | orocue
# Processing Record 17 of Set 6 | cherskiy
# Processing Record 18 of Set 6 | misratah
# Processing Record 19 of Set 6 | fairbanks
# Processing Record 20 of Set 6 | ostrovnoy
# Processing Record 21 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 22 of Set 6 | beringovskiy
# Processing Record 23 of Set 6 | emba
# Processing Record 24 of Set 6 | vestmanna
# Processing Record 25 of Set 6 | jacareacanga
# Processing Record 26 of Set 6 | severo-kurilsk
# Processing Record 27 of Set 6 | yellowknife
# Processing Record 28 of Set 6 | sechura
# Processing Record 29 of Set 6 | yar-sale
# Processing Record 30 of Set 6 | ilulissat
# Processing Record 31 of Set 6 | samarinda
# Processing Record 32 of Set 6 | cairns
# Processing Record 33 of Set 6 | puerto ayacucho
# Processing Record 34 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 35 of Set 6 | anadyr
# Processing Record 36 of Set 6 | bonavista
# Processing Record 37 of Set 6 | havre-saint-pierre
# Processing Record 38 of Set 6 | kloulklubed
# Processing Record 39 of Set 6 | victoria
# Processing Record 40 of Set 6 | cidreira
# Processing Record 41 of Set 6 | hami
# Processing Record 42 of Set 6 | tengzhou
# Processing Record 43 of Set 6 | sonoita
# Processing Record 44 of Set 6 | presidencia roque saenz pena
# Processing Record 45 of Set 6 | bolshoye nagatkino
# Processing Record 46 of Set 6 | hamadan
# Processing Record 47 of Set 6 | sorong
# Processing Record 48 of Set 6 | borogontsy
# Processing Record 49 of Set 6 | phonhong
# Processing Record 50 of Set 6 | progreso
# Processing Record 1 of Set 7 | chuy
# Processing Record 2 of Set 7 | ust-maya
# Processing Record 3 of Set 7 | iglas
# Processing Record 4 of Set 7 | bitburg
# Processing Record 5 of Set 7 | clonakilty
# Processing Record 6 of Set 7 | andenes
# Processing Record 7 of Set 7 | plettenberg bay
# Processing Record 8 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 9 of Set 7 | cravo norte
# Processing Record 10 of Set 7 | milkovo
# Processing Record 11 of Set 7 | pacific grove
# Processing Record 12 of Set 7 | tigil
# Processing Record 13 of Set 7 | vanimo
# Processing Record 14 of Set 7 | nhulunbuy
# Processing Record 15 of Set 7 | nome
# Processing Record 16 of Set 7 | bajo baudo
# City not found. Skipping...
# Processing Record 17 of Set 7 | kenai
# Processing Record 18 of Set 7 | preobrazheniye
# Processing Record 19 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 20 of Set 7 | yelatma
# Processing Record 21 of Set 7 | kalmunai
# Processing Record 22 of Set 7 | srednekolymsk
# Processing Record 23 of Set 7 | la ronge
# Processing Record 24 of Set 7 | bengkulu
# Processing Record 25 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 26 of Set 7 | dali
# Processing Record 27 of Set 7 | houston
# Processing Record 28 of Set 7 | vila franca do campo
# Processing Record 29 of Set 7 | leningradskiy
# Processing Record 30 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 31 of Set 7 | luba
# Processing Record 32 of Set 7 | kununurra
# Processing Record 33 of Set 7 | bloemfontein
# Processing Record 34 of Set 7 | sirohi
# Processing Record 35 of Set 7 | tarrafal
# Processing Record 36 of Set 7 | kutum
# Processing Record 37 of Set 7 | westport
# Processing Record 38 of Set 7 | nioki
# Processing Record 39 of Set 7 | taiyuan
# Processing Record 40 of Set 7 | awjilah
# Processing Record 41 of Set 7 | hofn
# Processing Record 42 of Set 7 | norman wells
# Processing Record 43 of Set 7 | goalpara
# Processing Record 44 of Set 7 | hebi
# Processing Record 45 of Set 7 | gravdal
# Processing Record 46 of Set 7 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 47 of Set 7 | listowel
# Processing Record 48 of Set 7 | lethem
# Processing Record 49 of Set 7 | urengoy
# Processing Record 50 of Set 7 | trapani
# Processing Record 1 of Set 8 | louga
# Processing Record 2 of Set 8 | amapa
# Processing Record 3 of Set 8 | los llanos de aridane
# Processing Record 4 of Set 8 | lusaka
# Processing Record 5 of Set 8 | liverpool
# Processing Record 6 of Set 8 | lata
# Processing Record 7 of Set 8 | nalut
# Processing Record 8 of Set 8 | murupara
# Processing Record 9 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 8 | tautira
# Processing Record 11 of Set 8 | salerno
# Processing Record 12 of Set 8 | sao gabriel da cachoeira
# Processing Record 13 of Set 8 | chara
# Processing Record 14 of Set 8 | taoudenni
# Processing Record 15 of Set 8 | qadirpur ran
# Processing Record 16 of Set 8 | kaseda
# Processing Record 17 of Set 8 | rivera
# Processing Record 18 of Set 8 | ouesso
# Processing Record 19 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 8 | pundaguitan
# Processing Record 21 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 8 | puro
# Processing Record 23 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 24 of Set 8 | nabire
# Processing Record 25 of Set 8 | haines junction
# Processing Record 26 of Set 8 | port blair
# Processing Record 27 of Set 8 | paamiut
# Processing Record 28 of Set 8 | meadow lake
# Processing Record 29 of Set 8 | kattivakkam
# Processing Record 30 of Set 8 | ginir
# Processing Record 31 of Set 8 | semey
# Processing Record 32 of Set 8 | antalaha
# Processing Record 33 of Set 8 | sola
# Processing Record 34 of Set 8 | helong
# Processing Record 35 of Set 8 | hamilton
# Processing Record 36 of Set 8 | domoni
# Processing Record 37 of Set 8 | krasnoarmeysk
# Processing Record 38 of Set 8 | ishigaki
# Processing Record 39 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 40 of Set 8 | sorland
# Processing Record 41 of Set 8 | paucartambo
# City not found. Skipping...
# Processing Record 42 of Set 8 | lorengau
# Processing Record 43 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 44 of Set 8 | hangal
# Processing Record 45 of Set 8 | svetlyy
# Processing Record 46 of Set 8 | frontignan
# Processing Record 47 of Set 8 | ammapettai
# Processing Record 48 of Set 8 | kuala terengganu
# Processing Record 49 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 8 | buique
# Processing Record 1 of Set 9 | upernavik
# Processing Record 2 of Set 9 | launceston
# Processing Record 3 of Set 9 | mega
# Processing Record 4 of Set 9 | curup
# Processing Record 5 of Set 9 | inirida
# Processing Record 6 of Set 9 | kodiak
# Processing Record 7 of Set 9 | port-gentil
# Processing Record 8 of Set 9 | santiago
# Processing Record 9 of Set 9 | neyshabur
# Processing Record 10 of Set 9 | broome
# Processing Record 11 of Set 9 | puerto lopez
# Processing Record 12 of Set 9 | diamantino
# Processing Record 13 of Set 9 | san policarpo
# Processing Record 14 of Set 9 | toora-khem
# Processing Record 15 of Set 9 | fare
# Processing Record 16 of Set 9 | fort nelson
# Processing Record 17 of Set 9 | mezen
# Processing Record 18 of Set 9 | tolaga bay
# Processing Record 19 of Set 9 | nyurba
# Processing Record 20 of Set 9 | acapulco
# Processing Record 21 of Set 9 | dubbo
# Processing Record 22 of Set 9 | clyde river
# Processing Record 23 of Set 9 | kingston
# Processing Record 24 of Set 9 | port macquarie
# Processing Record 25 of Set 9 | robertsport
# Processing Record 26 of Set 9 | leno
# Processing Record 27 of Set 9 | aksu
# Processing Record 28 of Set 9 | treinta y tres
# Processing Record 29 of Set 9 | comodoro rivadavia
# Processing Record 30 of Set 9 | witney
# Processing Record 31 of Set 9 | pucallpa
# Processing Record 32 of Set 9 | juneau
# Processing Record 33 of Set 9 | quelimane
# Processing Record 34 of Set 9 | alihe
# Processing Record 35 of Set 9 | port hardy
# Processing Record 36 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 9 | lehigh acres
# Processing Record 38 of Set 9 | itoman
# Processing Record 39 of Set 9 | viksoyri
# City not found. Skipping...
# Processing Record 40 of Set 9 | pringsewu
# Processing Record 41 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 42 of Set 9 | esil
# Processing Record 43 of Set 9 | galle
# Processing Record 44 of Set 9 | havoysund
# Processing Record 45 of Set 9 | talavera de la reina
# Processing Record 46 of Set 9 | calvia
# Processing Record 47 of Set 9 | eenhana
# Processing Record 48 of Set 9 | bambari
# Processing Record 49 of Set 9 | kurumkan
# Processing Record 50 of Set 9 | iwaki
# Processing Record 1 of Set 10 | kutoarjo
# Processing Record 2 of Set 10 | fort frances
# Processing Record 3 of Set 10 | kilindoni
# Processing Record 4 of Set 10 | izhma
# Processing Record 5 of Set 10 | te anau
# Processing Record 6 of Set 10 | talnakh
# Processing Record 7 of Set 10 | rio grande
# Processing Record 8 of Set 10 | borgarnes
# Processing Record 9 of Set 10 | abha
# Processing Record 10 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 11 of Set 10 | tigzirt
# Processing Record 12 of Set 10 | gasa
# Processing Record 13 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 14 of Set 10 | tessalit
# Processing Record 15 of Set 10 | aykhal
# Processing Record 16 of Set 10 | moron
# Processing Record 17 of Set 10 | jaypur
# Processing Record 18 of Set 10 | linguere
# Processing Record 19 of Set 10 | qaqortoq
# Processing Record 20 of Set 10 | miri
# Processing Record 21 of Set 10 | lillesand
# Processing Record 22 of Set 10 | bayir
# Processing Record 23 of Set 10 | deputatskiy
# Processing Record 24 of Set 10 | havelock
# Processing Record 25 of Set 10 | nanga eboko
# Processing Record 26 of Set 10 | poum
# Processing Record 27 of Set 10 | bairnsdale
# Processing Record 28 of Set 10 | woodward
# Processing Record 29 of Set 10 | thunder bay
# Processing Record 30 of Set 10 | port-de-bouc
# Processing Record 31 of Set 10 | asyut
# Processing Record 32 of Set 10 | sao joao da barra
# Processing Record 33 of Set 10 | slatina-timis
# Processing Record 34 of Set 10 | conceicao do araguaia
# Processing Record 35 of Set 10 | aswan
# Processing Record 36 of Set 10 | krasnoselkup
# Processing Record 37 of Set 10 | congonhas
# Processing Record 38 of Set 10 | majene
# Processing Record 39 of Set 10 | grand-santi
# Processing Record 40 of Set 10 | pakwach
# City not found. Skipping...
# Processing Record 41 of Set 10 | jujuy
# City not found. Skipping...
# Processing Record 42 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 10 | arteaga
# Processing Record 44 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 10 | dhidhdhoo
# Processing Record 46 of Set 10 | batemans bay
# Processing Record 47 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 48 of Set 10 | najran
# Processing Record 49 of Set 10 | alvaro obregon
# Processing Record 50 of Set 10 | barranca
# Processing Record 1 of Set 11 | knysna
# Processing Record 2 of Set 11 | lubango
# Processing Record 3 of Set 11 | oranjemund
# Processing Record 4 of Set 11 | daru
# Processing Record 5 of Set 11 | nikitinskiy
# Processing Record 6 of Set 11 | martin
# Processing Record 7 of Set 11 | amio
# Processing Record 8 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 9 of Set 11 | novoagansk
# Processing Record 10 of Set 11 | baturaja
# Processing Record 11 of Set 11 | sitka
# Processing Record 12 of Set 11 | guanhaes
# Processing Record 13 of Set 11 | mildura
# Processing Record 14 of Set 11 | grindavik
# Processing Record 15 of Set 11 | batticaloa
# Processing Record 16 of Set 11 | necochea
# Processing Record 17 of Set 11 | kunashak
# Processing Record 18 of Set 11 | guarapari
# Processing Record 19 of Set 11 | ippy
# Processing Record 20 of Set 11 | almeirim
# Processing Record 21 of Set 11 | la palma
# Processing Record 22 of Set 11 | damara
# Processing Record 23 of Set 11 | sri aman
# Processing Record 24 of Set 11 | jahrom
# City not found. Skipping...
# Processing Record 25 of Set 11 | tura
# Processing Record 26 of Set 11 | sampit
# Processing Record 27 of Set 11 | prieska
# Processing Record 28 of Set 11 | camacupa
# Processing Record 29 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 30 of Set 11 | nemuro
# Processing Record 31 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 11 | kyaikkami
# Processing Record 33 of Set 11 | sayat
# Processing Record 34 of Set 11 | juegang
# Processing Record 35 of Set 11 | tokur
# Processing Record 36 of Set 11 | lowestoft
# Processing Record 37 of Set 11 | hatillo
# Processing Record 38 of Set 11 | keti bandar
# Processing Record 39 of Set 11 | umba
# Processing Record 40 of Set 11 | baglung
# Processing Record 41 of Set 11 | acari
# Processing Record 42 of Set 11 | vucje
# Processing Record 43 of Set 11 | marsh harbour
# Processing Record 44 of Set 11 | redmond
# Processing Record 45 of Set 11 | batagay-alyta
# Processing Record 46 of Set 11 | mehamn
# Processing Record 47 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 48 of Set 11 | williams lake
# Processing Record 49 of Set 11 | pandan niog
# Processing Record 50 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 12 | marzuq
# Processing Record 2 of Set 12 | dujuma
# City not found. Skipping...
# Processing Record 3 of Set 12 | tilichiki
# Processing Record 4 of Set 12 | przhevalskoye
# Processing Record 5 of Set 12 | santa cruz de la palma
# Processing Record 6 of Set 12 | antofagasta
# Processing Record 7 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 8 of Set 12 | soyo
# Processing Record 9 of Set 12 | entebbe
# Processing Record 10 of Set 12 | pomabamba
# Processing Record 11 of Set 12 | ottawa
# Processing Record 12 of Set 12 | uthal
# Processing Record 13 of Set 12 | taquari
# Processing Record 14 of Set 12 | vao
# Processing Record 15 of Set 12 | lasa
# Processing Record 16 of Set 12 | esna
# Processing Record 17 of Set 12 | kyra
# Processing Record 18 of Set 12 | houma
# Processing Record 19 of Set 12 | libertador general san martin
# Processing Record 20 of Set 12 | bayshore gardens
# Processing Record 21 of Set 12 | acarau
# Processing Record 22 of Set 12 | bara
# Processing Record 23 of Set 12 | burica
# City not found. Skipping...
# Processing Record 24 of Set 12 | oriximina
# Processing Record 25 of Set 12 | champerico
# Processing Record 26 of Set 12 | cabo rojo
# Processing Record 27 of Set 12 | monrovia
# Processing Record 28 of Set 12 | florianopolis
# Processing Record 29 of Set 12 | trifos
# City not found. Skipping...
# Processing Record 30 of Set 12 | moa
# Processing Record 31 of Set 12 | suratgarh
# Processing Record 32 of Set 12 | stornoway
# Processing Record 33 of Set 12 | eyrarbakki
# Processing Record 34 of Set 12 | verkhoyansk
# Processing Record 35 of Set 12 | ribera
# Processing Record 36 of Set 12 | merritt island
# Processing Record 37 of Set 12 | natal
# Processing Record 38 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 39 of Set 12 | andros town
# Processing Record 40 of Set 12 | chumikan
# Processing Record 41 of Set 12 | mumford
# Processing Record 42 of Set 12 | miajadas
# Processing Record 43 of Set 12 | celestun
# Processing Record 44 of Set 12 | kiunga
# Processing Record 45 of Set 12 | lamu
# Processing Record 46 of Set 12 | schoningen
# Processing Record 47 of Set 12 | puerto quijarro
# Processing Record 48 of Set 12 | vestmannaeyjar
# Processing Record 49 of Set 12 | bathsheba
# Processing Record 50 of Set 12 | cap-aux-meules
# Processing Record 1 of Set 13 | banda aceh
# Processing Record 2 of Set 13 | tagab
# Processing Record 3 of Set 13 | rozsaszentmarton
# Processing Record 4 of Set 13 | ulladulla
# Processing Record 5 of Set 13 | saint anthony
# Processing Record 6 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 7 of Set 13 | fushan
# Processing Record 8 of Set 13 | port shepstone
# Processing Record 9 of Set 13 | svencioneliai
# Processing Record 10 of Set 13 | clarence town
# Processing Record 11 of Set 13 | vikhorevka
# Processing Record 12 of Set 13 | teknaf
# Processing Record 13 of Set 13 | tiznit
# Processing Record 14 of Set 13 | claveria
# Processing Record 15 of Set 13 | guanare
# Processing Record 16 of Set 13 | pochutla
# Processing Record 17 of Set 13 | kerema
# Processing Record 18 of Set 13 | araouane
# Processing Record 19 of Set 13 | langangen
# City not found. Skipping...
# Processing Record 20 of Set 13 | luderitz
# Processing Record 21 of Set 13 | calvinia
# Processing Record 22 of Set 13 | vallenar
# Processing Record 23 of Set 13 | gorontalo
# Processing Record 24 of Set 13 | ortakoy
# Processing Record 25 of Set 13 | non sung
# Processing Record 26 of Set 13 | sulurpeta
# City not found. Skipping...
# Processing Record 27 of Set 13 | srandakan
# Processing Record 28 of Set 13 | beira
# Processing Record 29 of Set 13 | ambikapur
# Processing Record 30 of Set 13 | shelkovskaya
# Processing Record 31 of Set 13 | cabedelo
# Processing Record 32 of Set 13 | mugumu
# Processing Record 33 of Set 13 | shelburne
# Processing Record 34 of Set 13 | bud
# Processing Record 35 of Set 13 | kanye
# Processing Record 36 of Set 13 | inhambane
# Processing Record 37 of Set 13 | abu dhabi
# Processing Record 38 of Set 13 | ritchie
# Processing Record 39 of Set 13 | marawi
# Processing Record 40 of Set 13 | spirit river
# Processing Record 41 of Set 13 | chicomuselo
# Processing Record 42 of Set 13 | takoradi
# Processing Record 43 of Set 13 | pareora
# Processing Record 44 of Set 13 | revelstoke
# Processing Record 45 of Set 13 | abnub
# Processing Record 46 of Set 13 | vuktyl
# Processing Record 47 of Set 13 | murdochville
# Processing Record 48 of Set 13 | juba
# Processing Record 49 of Set 13 | ordzhonikidze
# Processing Record 50 of Set 13 | pangai
# Processing Record 1 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 2 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 3 of Set 14 | neryungri
# Processing Record 4 of Set 14 | nanlong
# Processing Record 5 of Set 14 | la asuncion
# Processing Record 6 of Set 14 | cockburn town
# Processing Record 7 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 8 of Set 14 | taksimo
# Processing Record 9 of Set 14 | stribro
# Processing Record 10 of Set 14 | tateyama
# Processing Record 11 of Set 14 | pocos de caldas
# Processing Record 12 of Set 14 | concordia
# Processing Record 13 of Set 14 | kargasok
# Processing Record 14 of Set 14 | porbandar
# Processing Record 15 of Set 14 | mwense
# Processing Record 16 of Set 14 | freeport
# Processing Record 17 of Set 14 | roma
# Processing Record 18 of Set 14 | las palmas
# Processing Record 19 of Set 14 | machaneng
# Processing Record 20 of Set 14 | dekoa
# City not found. Skipping...
# Processing Record 21 of Set 14 | litoral del san juan
# City not found. Skipping...
# Processing Record 22 of Set 14 | awbari
# Processing Record 23 of Set 14 | nizhnevartovsk
# Processing Record 24 of Set 14 | usinsk
# Processing Record 25 of Set 14 | sambava
# Processing Record 26 of Set 14 | sinjar
# Processing Record 27 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 28 of Set 14 | florence
# Processing Record 29 of Set 14 | barstow
# Processing Record 30 of Set 14 | sur
# Processing Record 31 of Set 14 | bambanglipuro
# Processing Record 32 of Set 14 | pietersburg
# Processing Record 33 of Set 14 | high level
# Processing Record 34 of Set 14 | eyl
# Processing Record 35 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 36 of Set 14 | rawson
# Processing Record 37 of Set 14 | lexington
# Processing Record 38 of Set 14 | ca mau
# Processing Record 39 of Set 14 | gladstone
# Processing Record 40 of Set 14 | marsa matruh
# Processing Record 41 of Set 14 | ancud
# Processing Record 42 of Set 14 | tucuma
# Processing Record 43 of Set 14 | san pedro de ycuamandiyu
# Processing Record 44 of Set 14 | sylvania
# Processing Record 45 of Set 14 | muli
# Processing Record 46 of Set 14 | banfora
# Processing Record 47 of Set 14 | fort-shevchenko
# Processing Record 48 of Set 14 | sakakah
# Processing Record 49 of Set 14 | neuquen
# Processing Record 50 of Set 14 | xining
# Processing Record 1 of Set 15 | berlevag
# Processing Record 2 of Set 15 | tam ky
# Processing Record 3 of Set 15 | faya
# Processing Record 4 of Set 15 | bergen
# Processing Record 5 of Set 15 | mogadishu
# Processing Record 6 of Set 15 | tres arroyos
# Processing Record 7 of Set 15 | novi sanzhary
# Processing Record 8 of Set 15 | dossor
# Processing Record 9 of Set 15 | luxor
# Processing Record 10 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 11 of Set 15 | katsuura
# Processing Record 12 of Set 15 | qinzhou
# Processing Record 13 of Set 15 | kabompo
# Processing Record 14 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 15 | yerbogachen
# Processing Record 16 of Set 15 | bilma
# Processing Record 17 of Set 15 | hit
# Processing Record 18 of Set 15 | karangasem
# Processing Record 19 of Set 15 | chitral
# Processing Record 20 of Set 15 | atar
# Processing Record 21 of Set 15 | marseille
# Processing Record 22 of Set 15 | marystown
# Processing Record 23 of Set 15 | terney
# Processing Record 24 of Set 15 | ornskoldsvik
# Processing Record 25 of Set 15 | azrow
# City not found. Skipping...
# Processing Record 26 of Set 15 | puerto cabezas
# Processing Record 27 of Set 15 | tanout
# Processing Record 28 of Set 15 | bereznik
# Processing Record 29 of Set 15 | bezhta
# Processing Record 30 of Set 15 | xihe
# Processing Record 31 of Set 15 | ust-kuyga
# Processing Record 32 of Set 15 | wellen
# Processing Record 33 of Set 15 | tukrah
# Processing Record 34 of Set 15 | huntsville
# Processing Record 35 of Set 15 | sulangan
# Processing Record 36 of Set 15 | elizabeth city
# Processing Record 37 of Set 15 | korla
# Processing Record 38 of Set 15 | careiro da varzea
# Processing Record 39 of Set 15 | luang prabang
# Processing Record 40 of Set 15 | rexburg
# Processing Record 41 of Set 15 | punta gorda
# Processing Record 42 of Set 15 | scottsburgh
# City not found. Skipping...
# Processing Record 43 of Set 15 | podporozhye
# Processing Record 44 of Set 15 | terrace bay
# Processing Record 45 of Set 15 | codrington
# Processing Record 46 of Set 15 | henties bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 666

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Rikitea -23.1203 -134.9692     71.87        86         100
# 1       Namatanai  -3.6667  152.4333     84.45        62          92
# 2           Pevek  69.7008  170.3133     -7.91       100          98
# 3          Faanui -16.4833 -151.7500     79.14        75          55
# 4   Mount Gambier -37.8333  140.7667     65.88        50           3
# 5          Harper   4.3750   -7.7169     78.06        83          15
# 6       Saskylakh  71.9167  114.0833    -34.42       100          84
# 7          Ixtapa  20.7000 -105.2000     78.22        73           0
# 8            Lebu -37.6167  -73.6500     58.14        91         100
# 9  Ciudad Bolivar   8.1222  -63.5497     80.35        75         100
#
#    Wind Speed Country Current Description
# 0        9.01      PF          light rain
# 1        7.40      PG     overcast clouds
# 2        3.96      RU     overcast clouds
# 3        4.03      PF       moderate rain
# 4        8.50      AU           clear sky
# 5        6.58      LR          few clouds
# 6        2.55      RU       broken clouds
# 7        9.22      MX           clear sky
# 8        9.15      CL          light rain
# 9        9.80      VE     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Rikitea      PF -23.1203 -134.9692     71.87        86         100
# 1       Namatanai      PG  -3.6667  152.4333     84.45        62          92
# 2           Pevek      RU  69.7008  170.3133     -7.91       100          98
# 3          Faanui      PF -16.4833 -151.7500     79.14        75          55
# 4   Mount Gambier      AU -37.8333  140.7667     65.88        50           3
# 5          Harper      LR   4.3750   -7.7169     78.06        83          15
# 6       Saskylakh      RU  71.9167  114.0833    -34.42       100          84
# 7          Ixtapa      MX  20.7000 -105.2000     78.22        73           0
# 8            Lebu      CL -37.6167  -73.6500     58.14        91         100
# 9  Ciudad Bolivar      VE   8.1222  -63.5497     80.35        75         100
#
#    Wind Speed Current Description
# 0        9.01          light rain
# 1        7.40     overcast clouds
# 2        3.96     overcast clouds
# 3        4.03       moderate rain
# 4        8.50           clear sky
# 5        6.58          few clouds
# 6        2.55       broken clouds
# 7        9.22           clear sky
# 8        9.15          light rain
# 9        9.80     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "./WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
